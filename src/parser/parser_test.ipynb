# %%
import sys
sys.path.append('/Users/mac/PycharmProjects/document-transformation/src/parser/NDD')
sys.path.append('/Users/mac/PycharmProjects/document-transformation/src/parser/NARDR')
import NARDR_parser , NDD_parser

# %%
NARDR_parser.get_NANDR_data('../template_generator/NARDR/output/Contents/section0.xml')
# Out:
# {'실무자1부서': '일제강제동원피해자지원재단 운영관리국',
#  '실무자1이름': '황동준 국장',
#  '실무자1전화번호': '02-721-1805',
#  '실무자2부서': '행정안전부 사회통합지원과',
#  '실무자2이름': '김영욱 사무관',
#  '실무자2전화번호': '044-205-3267',
#  '실무자3부서': '과거사관련업무지원단',
#  '실무자3이름': '강고원 서기관',
#  '실무자3전화번호': '044-205-6538',
#  '요청8': '일제강제동원피해자 지원관련',
#  '8-1 요청 세부사항': '행정안전부가 먼저 외교부, 문체부, 일본정부기관 등에 군함도 강제동원피해사실 표기 및 강제동원피해알리기, 항의 등 실적 및 관련 수발신 공문 일체                                    ',
#  '8-1 답변 세부사항': '의원님께서 요구하신 8-1번 건과 관련한 우리 부 산하 공공기관인 일제강제동원피해자지원재단의 관계 목록과 공문 일체는 별첨1~2로 제출합니다.                                    ',
#  '8-2 요청 세부사항': '일제강제동원피해자 지원 및 강제동원피해사실 표기 및 항의관련 행정안전부의 역할 및 임무                                    ',
#  '8-2 답변 세부사항': '8-2번 건과 관련하여 아래와 같은 붙임 파일로 답변 드립니다.                                    ',
#  '붙임1': '요구 자료에 대한 답변자료 1부'}

# %%
NDD_parser.get_NDD_data('../template_generator/NDD/static/html/0113.html')
# Out:
# {'접수번호': '7250052',
#  '접수일': '22/09/01',
#  '공개여부': '질의응답',
#  '담당자': '김범유 주무관',
#  '전화번호': '044-205-2267',
#  '인사말': '안녕하십니까? 행정안전부 정보공개정책과입니다.귀하의 정보공개청구(접수번호 7250052)건에 대하여 다음과 같이 공개 결정으로 답변드립니다.',
#  '질의1': '1.공공기관의 정보공개에 관한 법률 제18조(이의신청)② 국가기관 등은 제1항에 따른 이의신청이 있는 경우에는 심의회를 개최하여야 한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 개최하지 아니할 수 있다.1.심의회의 심의를 이미 거친 사항2.단순ㆍ반복적인 청구"이외에 정보공개 심의회를 개최할 수 있는 규정과,\n',
#  '답변1': '정보공개법 제18조(이의신청) ② 국가기관 등은 제1항에 따른 이의신청이 있는 경우에는 심의회를 개최하여야 한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 개최하지 아니할 수 있다.1. 심의회의 심의를 이미 거친 사항2. 단순·반복적인 청구3. 법령에 따라 비밀로 규정된 정보에 대한 청구\n',
#  '질의2': '동법②국가기관 등은 제1항에 따른 이의신청이 있는 경우에는 심의회를 개최하여야 한다. 다만, 다음 각 호의 어느 하나에 해당하는 경우에는 개최하지 아니할 수 있다.1호, 공개 청구된 정보의 공개 여부를 결정하기 곤란한 사항“ 이외에 정보공개 심의회 할 수 있는 규정을 정보공개 청구합니다.\n',
#  '답변2': '정보공개법 시행령 제11조(정보공개심의회) ② 심의회는 다음 각 호의 사항을 심의한다.\n',
# ...
